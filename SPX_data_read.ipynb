# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Data/SPX_opt_2019.csv")

# %%
df
# Out:
#          Unnamed: 0     secid        date               symbol  symbol_flag  \
# 0                 0  108105.0  2019-01-02   SPX 190118C1000000            1
# 1                 1  108105.0  2019-01-02   SPX 190118C1025000            1
# 2                 2  108105.0  2019-01-02   SPX 190118C1050000            1
# 3                 3  108105.0  2019-01-02   SPX 190118C1075000            1
# 4                 4  108105.0  2019-01-02   SPX 190118C1100000            1
# ...             ...       ...         ...                  ...          ...
# 3566102       66102  108105.0  2019-12-31  SPXW 201231P4200000            1
# 3566103       66103  108105.0  2019-12-31  SPXW 201231P4300000            1
# 3566104       66104  108105.0  2019-12-31  SPXW 201231P4400000            1
# 3566105       66105  108105.0  2019-12-31  SPXW 201231P4500000            1
# 3566106       66106  108105.0  2019-12-31  SPXW 201231P4600000            1
#
# ...

# %%
df.strike_price.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.impl_volatility.plot.kde()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_36850/4219303218.py in <module>
# ----> 1 df.impl_volatility.plot.kde()
#
# ~/.local/lib/python3.8/site-packages/pandas/plotting/_core.py in kde(self, bw_method, ind, **kwargs)
#    1419             >>> ax = df.plot.kde(ind=[1, 2, 3, 4, 5, 6])
#    1420         """
# -> 1421         return self(kind="kde", bw_method=bw_method, ind=ind, **kwargs)
#    1422
#    1423     density = kde
#
# ~/.local/lib/python3.8/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# ~/.local/lib/python3.8/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'secid', 'date', 'symbol', 'symbol_flag', 'exdate',
#        'last_date', 'cp_flag', 'strike_price', 'best_bid', 'best_offer',
#        'volume', 'open_interest', 'impl_volatility', 'delta', 'gamma', 'vega',
#        'theta', 'optionid', 'cfadj', 'am_settlement', 'contract_size',
#        'ss_flag', 'forward_price', 'expiry_indicator', 'root', 'suffix'],
#       dtype='object')
