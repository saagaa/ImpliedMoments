# %%
import wrds

# %%
conn = wrds.Connection()  
conn.create_pgpass_file()
# Out:
# Enter your WRDS username [anshul]:ansaggar
# Enter your password:········
# WRDS recommends setting up a .pgpass file.
# Create .pgpass file now [y/n]?: y
# Created .pgpass file successfully.
# Loading library list...
# Done

# %%
conn

# %%
conn.list_libraries('cboe')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_14696/2664349671.py in <module>
# ----> 1 conn.list_libraries('cboe')
#
# TypeError: list_libraries() takes 1 positional argument but 2 were given

# %%
conn.describe_table(library='cboe_all', table='cboe')
# Out:
# Approximately 12712 rows in cboe_all.cboe.
#     name  nullable              type
# 0   date      True              DATE
# 1   vixo      True  DOUBLE_PRECISION
# 2   vixh      True  DOUBLE_PRECISION
# 3   vixl      True  DOUBLE_PRECISION
# 4    vix      True  DOUBLE_PRECISION
# 5   vxoo      True  DOUBLE_PRECISION
# 6   vxoh      True  DOUBLE_PRECISION
# 7   vxol      True  DOUBLE_PRECISION
# 8    vxo      True  DOUBLE_PRECISION
# 9   vxno      True  DOUBLE_PRECISION
# 10  vxnh      True  DOUBLE_PRECISION
# 11  vxnl      True  DOUBLE_PRECISION
# 12   vxn      True  DOUBLE_PRECISION
# 13  vxdo      True  DOUBLE_PRECISION
# 14  vxdh      True  DOUBLE_PRECISION
# 15  vxdl      True  DOUBLE_PRECISION
# 16   vxd      True  DOUBLE_PRECISION

# %%
conn.describe_table(library='cboe', table='cboe')
# Out:
# Approximately 12712 rows in cboe.cboe.
#     name  nullable              type
# 0   date      True              DATE
# 1   vixo      True  DOUBLE_PRECISION
# 2   vixh      True  DOUBLE_PRECISION
# 3   vixl      True  DOUBLE_PRECISION
# 4    vix      True  DOUBLE_PRECISION
# 5   vxoo      True  DOUBLE_PRECISION
# 6   vxoh      True  DOUBLE_PRECISION
# 7   vxol      True  DOUBLE_PRECISION
# 8    vxo      True  DOUBLE_PRECISION
# 9   vxno      True  DOUBLE_PRECISION
# 10  vxnh      True  DOUBLE_PRECISION
# 11  vxnl      True  DOUBLE_PRECISION
# 12   vxn      True  DOUBLE_PRECISION
# 13  vxdo      True  DOUBLE_PRECISION
# 14  vxdh      True  DOUBLE_PRECISION
# 15  vxdl      True  DOUBLE_PRECISION
# 16   vxd      True  DOUBLE_PRECISION

# %%
df = conn.get_table(library='cboe', table='cboe')

# %%
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df.index=df.date

# %%
df[df.columns[:4]].plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
conn.list_libraries()
# Out:
# ['aha',
#  'aha_sample',
#  'ahasamp',
#  'audit',
#  'audit_audit_comp',
#  'audit_common',
#  'audit_corp_legal',
#  'auditsmp',
#  'auditsmp_all',
#  'bank',
#  'blab',
#  'block',
#  'block_all',
#  'boardex',
#  'boardex_na',
#  'boardex_trial',
#  'boardsmp',
#  'bvd',
#  'bvd_ama_large',
#  'bvd_ama_medium',
#  'bvd_ama_small',
#  'bvd_ama_verylarge',
#  'bvd_orbis_large',
#  'bvd_orbis_medium',
#  'bvd_orbis_small',
#  'bvdsamp',
#  'calcbench_trial',
#  'calcbnch',
#  'cboe',
#  'cboe_all',
#  'centris',
#  'ciq',
#  'ciqsamp',
#  'ciqsamp_common',
#  'ciqsamp_transcripts',
#  'cisdm',
#  'cisdmsmp',
#  'clrvt',
#  'clrvtsmp',
#  'columnar',
#  'comp',
#  'comp_bank',
#  'comp_bank_daily',
#  'comp_execucomp',
#  'comp_global',
#  'comp_global_daily',
#  'comp_na_annual_all',
#  'comp_na_daily_all',
#  'comp_na_monthly_all',
#  'comp_segments_hist',
#  'comp_segments_hist_daily',
#  'comp_urq',
#  'compa',
#  'compb',
#  'compbd',
#  'compdcur',
#  'compg',
#  'compgd',
# ...

# %%
'optionm',
 'optionm_all',
 'optionmsamp_europe',
 'optionmsamp_us',
# Out:
#   File "/tmp/ipykernel_14696/3377705034.py", line 2
#     'optionm_all',
#     ^
# IndentationError: unexpected indent

# %%
 conn.list_tables(library='optionmsamp_us')
# Out:
# ['distrd',
#  'exchgd',
#  'hvold2014',
#  'opinfd',
#  'opprcd2014',
#  'opvold',
#  'secnmd',
#  'secprd',
#  'secprd2014',
#  'securd1',
#  'stdopd2014',
#  'vsurfd2014']

# %%
for table in  conn.list_tables(library='optionmsamp_us'):
    conn.describe_table(library='optionmsamp_us', table = table)
# Out:
# Approximately 23 rows in optionmsamp_us.distrd.
# Approximately 1 rows in optionmsamp_us.exchgd.
# Approximately 130 rows in optionmsamp_us.hvold2014.
# Approximately 1 rows in optionmsamp_us.opinfd.
# Approximately 36742 rows in optionmsamp_us.opprcd2014.
# Approximately 30 rows in optionmsamp_us.opvold.
# Approximately 3 rows in optionmsamp_us.secnmd.
# Approximately 10 rows in optionmsamp_us.secprd.
# Approximately 10 rows in optionmsamp_us.secprd2014.
# Approximately 1 rows in optionmsamp_us.securd1.
# Approximately 180 rows in optionmsamp_us.stdopd2014.
# Approximately 2328 rows in optionmsamp_us.vsurfd2014.

# %%
conn.describe_table(library='optionmsamp_us', table = 'opprcd2014')
# Out:
# Approximately 36742 rows in optionmsamp_us.opprcd2014.
#                name  nullable              type
# 0             secid      True  DOUBLE_PRECISION
# 1              date      True              DATE
# 2            symbol      True       VARCHAR(21)
# 3       symbol_flag      True        VARCHAR(1)
# 4            exdate      True              DATE
# 5         last_date      True              DATE
# 6           cp_flag      True        VARCHAR(1)
# 7      strike_price      True  DOUBLE_PRECISION
# 8          best_bid      True  DOUBLE_PRECISION
# 9        best_offer      True  DOUBLE_PRECISION
# 10           volume      True  DOUBLE_PRECISION
# 11    open_interest      True  DOUBLE_PRECISION
# 12  impl_volatility      True  DOUBLE_PRECISION
# 13            delta      True  DOUBLE_PRECISION
# 14            gamma      True  DOUBLE_PRECISION
# 15             vega      True  DOUBLE_PRECISION
# 16            theta      True  DOUBLE_PRECISION
# ...

# %%
for table in  conn.list_tables(library='optionm_all'):
    conn.describe_table(library='optionm_all', table = table)
# Out:
# Approximately 615303 rows in optionm_all.distrd.
# Approximately 4143075 rows in optionm_all.distrprojd1996.
# Approximately 4662843 rows in optionm_all.distrprojd1997.
# Approximately 5123560 rows in optionm_all.distrprojd1998.
# Approximately 5234165 rows in optionm_all.distrprojd1999.
# Approximately 4119284 rows in optionm_all.distrprojd2000.
# Approximately 3542986 rows in optionm_all.distrprojd2001.
# Approximately 3817549 rows in optionm_all.distrprojd2002.
# Approximately 4130654 rows in optionm_all.distrprojd2003.
# Approximately 4592880 rows in optionm_all.distrprojd2004.
# Approximately 5217159 rows in optionm_all.distrprojd2005.
# Approximately 5840466 rows in optionm_all.distrprojd2006.
# Approximately 6810808 rows in optionm_all.distrprojd2007.
# Approximately 7242549 rows in optionm_all.distrprojd2008.
# Approximately 6918787 rows in optionm_all.distrprojd2009.
# Approximately 7081560 rows in optionm_all.distrprojd2010.
# ...
